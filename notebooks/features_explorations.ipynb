# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Datasets

# %%
df_events = pd.read_csv("../data/events.csv")
df_products = pd.read_csv("../data/products.csv")

# %% [markdown]
# # Understanding Events

# %% [markdown]
# ## Show Events

# %% [markdown]
# ### Events Schema

# %%
df_events.dtypes
# Out:
# user_id       str
# product_id    str
# event_type    str
# timestamp     str
# dtype: object

# %% [markdown]
# ### Events Sample

# %%
df_events.head()
# Out:
#   user_id product_id   event_type            timestamp
# 0  u_0231      p_042         view  2026-01-01 00:09:00
# 1  u_0078      p_012        click  2026-01-01 00:09:00
# 2  u_0078      p_012         view  2026-01-01 00:19:00
# 3  u_0322      p_059  add_to_cart  2026-01-01 00:28:00
# 4  u_0121      p_045  add_to_cart  2026-01-01 00:37:00

# %% [markdown]
# # Understanding Products

# %% [markdown]
# ## Show Products

# %% [markdown]
# ### Products Schema

# %%
df_products.dtypes
# Out:
# product_id              str
# category                str
# price               float64
# avg_rating          float64
# popularity_score    float64
# dtype: object

# %% [markdown]
# ### Products Sample

# %%
df_products.head()
# Out:
#   product_id category   price  avg_rating  popularity_score
# 0      p_000  esporte  115.19         3.1             0.652
# 1      p_001   livros  406.24         4.3             0.162
# 2      p_002   beleza   46.82         3.6             0.069
# 3      p_003   livros  729.27         4.0             0.077
# 4      p_004   livros  221.85         4.8             0.174
